# %% [markdown]
# # Calculate Distances Between Schools and Tournament Sites
#
# ## Import data and packages

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point

# import all geocoded results, including schools and tournament sites
allResults = pd.read_csv('../data/cleaned/geocoded_results.csv')
allResults
# Out:
#       seed school_common_name                site    year       id  \
# 0      1.0               Duke        Columbia, SC  2019.0    20190
# 1      1.0            Gonzaga  Salt Lake City, UT  2019.0    20191
# 2      1.0     North Carolina        Columbus, OH  2019.0    20192
# 3      1.0           Virginia        Columbia, SC  2019.0    20193
# 4      2.0     Michigan State      Des Moines, IA  2019.0    20194
# ...    ...                ...                 ...     ...      ...
# 1115   NaN                NaN     Albuquerque, NM     NaN  1985555
# 1116   NaN                NaN        Hartford, CT     NaN  1985556
# 1117   NaN                NaN           Tulsa, OK     NaN  1985557
# 1118   NaN                NaN          Dayton, OH     NaN  1985558
# 1119   NaN                NaN  Salt Lake City, UT     NaN  1985559
#
#                                  school_full_name         team  \
# 0                                 Duke University  Blue Devils
# 1                              Gonzaga University     Bulldogs
# 2     University of North Carolina at Chapel Hill    Tar Heels
# 3                          University of Virginia    Cavaliers
# 4                       Michigan State University     Spartans
# ...                                           ...          ...
# 1115                                          NaN          NaN
# 1116                                          NaN          NaN
# 1117                                          NaN          NaN
# 1118                                          NaN          NaN
# 1119                                          NaN          NaN
#
#                  city           state                   type  \
# 0              Durham  North Carolina  Private/Non-sectarian
# 1             Spokane      Washington       Private/Catholic
# 2         Chapel Hill  North Carolina                  State
# 3     Charlottesville        Virginia                  State
# 4        East Lansing        Michigan                  State
# ...               ...             ...                    ...
# 1115              NaN             NaN                    NaN
# 1116              NaN             NaN                    NaN
# 1117              NaN             NaN                    NaN
# 1118              NaN             NaN                    NaN
# 1119              NaN             NaN                    NaN
#
#                      conference  \
# 0     Atlantic Coast Conference
# 1         West Coast Conference
# 2     Atlantic Coast Conference
# 3     Atlantic Coast Conference
# 4            Big Ten Conference
# ...                         ...
# 1115                        NaN
# 1116                        NaN
# 1117                        NaN
# 1118                        NaN
# 1119                        NaN
#
#                                                 address         lat        lng
# 0                 Duke University Durham North Carolina  -78.944230  36.000156
# 1                 Gonzaga University Spokane Washington -117.403044  47.666739
# 2     University of North Carolina at Chapel Hill Ch...  -79.047753  35.905035
# 3       University of Virginia Charlottesville Virginia  -78.505500  38.041058
# 4       Michigan State University East Lansing Michigan  -84.477916  42.718568
# ...                                                 ...         ...        ...
# 1115                                    Albuquerque, NM -106.650985  35.084103
# 1116                                       Hartford, CT  -72.690855  41.764582
# 1117                                          Tulsa, OK  -95.992911  36.155681
# 1118                                         Dayton, OH  -84.191607  39.758948
# 1119                                 Salt Lake City, UT -111.886798  40.759620
#
# [1120 rows x 14 columns]

# %% [markdown]
# ## Convert to GeoDataFrame
#
# Using Shapely, latitude and longitude coordinates can be converted to Point geometry. Using the UTM 14N Coordinate Reference System will allow the distance between schools and sites to be calculated in meters rather than degrees.

# %%
# convert latitude and longitude to Point geometry
geoms = [Point(xy) for xy in zip(allResults.lng, allResults.lat)]

# UTM 14N CRS to calculate distance in meters
crs = {'init': 'epsg:32614'}  # UTM 14N for US

# convert to geodataframe
resultsGdf = gpd.GeoDataFrame(allResults, crs=crs, geometry=geoms)
resultsGdf
# Out:
#       seed school_common_name                site    year       id  \
# 0      1.0               Duke        Columbia, SC  2019.0    20190
# 1      1.0            Gonzaga  Salt Lake City, UT  2019.0    20191
# 2      1.0     North Carolina        Columbus, OH  2019.0    20192
# 3      1.0           Virginia        Columbia, SC  2019.0    20193
# 4      2.0     Michigan State      Des Moines, IA  2019.0    20194
# ...    ...                ...                 ...     ...      ...
# 1115   NaN                NaN     Albuquerque, NM     NaN  1985555
# 1116   NaN                NaN        Hartford, CT     NaN  1985556
# 1117   NaN                NaN           Tulsa, OK     NaN  1985557
# 1118   NaN                NaN          Dayton, OH     NaN  1985558
# 1119   NaN                NaN  Salt Lake City, UT     NaN  1985559
#
#                                  school_full_name         team  \
# 0                                 Duke University  Blue Devils
# 1                              Gonzaga University     Bulldogs
# 2     University of North Carolina at Chapel Hill    Tar Heels
# 3                          University of Virginia    Cavaliers
# 4                       Michigan State University     Spartans
# ...                                           ...          ...
# 1115                                          NaN          NaN
# 1116                                          NaN          NaN
# 1117                                          NaN          NaN
# 1118                                          NaN          NaN
# 1119                                          NaN          NaN
#
#                  city           state                   type  \
# 0              Durham  North Carolina  Private/Non-sectarian
# 1             Spokane      Washington       Private/Catholic
# 2         Chapel Hill  North Carolina                  State
# 3     Charlottesville        Virginia                  State
# 4        East Lansing        Michigan                  State
# ...               ...             ...                    ...
# 1115              NaN             NaN                    NaN
# 1116              NaN             NaN                    NaN
# 1117              NaN             NaN                    NaN
# 1118              NaN             NaN                    NaN
# 1119              NaN             NaN                    NaN
#
#                      conference  \
# 0     Atlantic Coast Conference
# 1         West Coast Conference
# 2     Atlantic Coast Conference
# 3     Atlantic Coast Conference
# 4            Big Ten Conference
# ...                         ...
# 1115                        NaN
# 1116                        NaN
# 1117                        NaN
# 1118                        NaN
# 1119                        NaN
#
#                                                 address         lat  \
# 0                 Duke University Durham North Carolina  -78.944230
# 1                 Gonzaga University Spokane Washington -117.403044
# 2     University of North Carolina at Chapel Hill Ch...  -79.047753
# 3       University of Virginia Charlottesville Virginia  -78.505500
# 4       Michigan State University East Lansing Michigan  -84.477916
# ...                                                 ...         ...
# 1115                                    Albuquerque, NM -106.650985
# 1116                                       Hartford, CT  -72.690855
# 1117                                          Tulsa, OK  -95.992911
# 1118                                         Dayton, OH  -84.191607
# 1119                                 Salt Lake City, UT -111.886798
#
#             lng                 geometry
# 0     36.000156   POINT (36.000 -78.944)
# 1     47.666739  POINT (47.667 -117.403)
# 2     35.905035   POINT (35.905 -79.048)
# 3     38.041058   POINT (38.041 -78.505)
# 4     42.718568   POINT (42.719 -84.478)
# ...         ...                      ...
# 1115  35.084103  POINT (35.084 -106.651)
# 1116  41.764582   POINT (41.765 -72.691)
# 1117  36.155681   POINT (36.156 -95.993)
# 1118  39.758948   POINT (39.759 -84.192)
# 1119  40.759620  POINT (40.760 -111.887)
#
# [1120 rows x 15 columns]

# %% [markdown]
# ## Separate school and site data
#
# The school and tournament site locations will be matched through their shared id, but it will be easier to iterate through the two simultaneously if the dataframes are separated. Furthermore, the dataframes will be saved separately.

# %%
# filter for site locations, which will have NA for seed values
sites = resultsGdf[resultsGdf.seed.isna()]

# filter for schools, which will have integers/non-NA values for the seed column
schools = resultsGdf[resultsGdf.seed.isna() == False]

# %% [markdown]
# ## Calculate distance
#
# With the locations set to the UTM 14N coordinate reference system, the school dataset can be iterated over, matched to the corresponding sites through a shared id, and the distance between the two calculated. The distance results are converted to miles.

# %%
# suppress warning for copying from slice of dataframe
pd.options.mode.chained_assignment = None  # default='warn'

# calculate distance between schools and sites with matching id
# find geometry column of school and site with each id - has to be further subset by the indexed value
# convert distance to miles
distance = [schools.loc[schools.id == uid, 'geometry'][i]
     .distance(sites.loc[sites.id == uid, 'geometry'][sites.loc[sites.id == uid, 'geometry'].index[0]])
     * 100000/1609 for i, uid in enumerate(schools.id)]

# %% [markdown]
# ## Apply distance list to school and site dataframes

# %%
# set distance as new column in schools dataframe
schools['distance'] = distance
sites['distance'] = distance

# check
schools
# Out:
#      seed school_common_name                site    year       id  \
# 0     1.0               Duke        Columbia, SC  2019.0    20190
# 1     1.0            Gonzaga  Salt Lake City, UT  2019.0    20191
# 2     1.0     North Carolina        Columbus, OH  2019.0    20192
# 3     1.0           Virginia        Columbia, SC  2019.0    20193
# 4     2.0     Michigan State      Des Moines, IA  2019.0    20194
# ..    ...                ...                 ...     ...      ...
# 555   3.0           NC State     Albuquerque, NM  1985.0  1985555
# 556   4.0     Loyola–Chicago        Hartford, CT  1985.0  1985556
# 557   4.0         Ohio State           Tulsa, OK  1985.0  1985557
# 558   4.0                LSU          Dayton, OH  1985.0  1985558
# 559   4.0               UNLV  Salt Lake City, UT  1985.0  1985559
#
#                                 school_full_name         team  \
# 0                                Duke University  Blue Devils
# 1                             Gonzaga University     Bulldogs
# 2    University of North Carolina at Chapel Hill    Tar Heels
# 3                         University of Virginia    Cavaliers
# 4                      Michigan State University     Spartans
# ..                                           ...          ...
# 555              North Carolina State University     Wolfpack
# 556                    Loyola University Chicago     Ramblers
# 557                    The Ohio State University     Buckeyes
# 558                   Louisiana State University       Tigers
# 559              University of Nevada, Las Vegas       Rebels
#
#                 city           state                   type  \
# 0             Durham  North Carolina  Private/Non-sectarian
# 1            Spokane      Washington       Private/Catholic
# 2        Chapel Hill  North Carolina                  State
# 3    Charlottesville        Virginia                  State
# 4       East Lansing        Michigan                  State
# ..               ...             ...                    ...
# 555          Raleigh  North Carolina                  State
# 556          Chicago        Illinois       Private/Catholic
# 557         Columbus            Ohio                  State
# 558      Baton Rouge       Louisiana                  State
# 559         Paradise          Nevada                  State
#
#                      conference  \
# 0     Atlantic Coast Conference
# 1         West Coast Conference
# 2     Atlantic Coast Conference
# 3     Atlantic Coast Conference
# 4            Big Ten Conference
# ..                          ...
# 555   Atlantic Coast Conference
# 556  Missouri Valley Conference
# 557          Big Ten Conference
# 558     Southeastern Conference
# 559    Mountain West Conference
#
#                                                address         lat        lng  \
# 0                Duke University Durham North Carolina  -78.944230  36.000156
# 1                Gonzaga University Spokane Washington -117.403044  47.666739
# 2    University of North Carolina at Chapel Hill Ch...  -79.047753  35.905035
# 3      University of Virginia Charlottesville Virginia  -78.505500  38.041058
# 4      Michigan State University East Lansing Michigan  -84.477916  42.718568
# ..                                                 ...         ...        ...
# 555  North Carolina State University Raleigh North ...  -78.674087  35.771850
# 556         Loyola University Chicago Chicago Illinois  -87.668422  41.944842
# 557            The Ohio State University Columbus Ohio  -83.028663  40.005709
# 558   Louisiana State University Baton Rouge Louisiana  -91.185968  30.405709
# 559                               UNLV Paradise Nevada -115.141832  36.107155
#
#                     geometry     distance
# 0     POINT (36.000 -78.944)   179.765685
# 1    POINT (47.667 -117.403)   549.380264
# 2     POINT (35.905 -79.048)   352.052893
# 3     POINT (38.041 -78.505)   296.237023
# 4     POINT (42.719 -84.478)   571.484627
# ..                       ...          ...
# 555   POINT (35.772 -78.674)  1739.300819
# 556   POINT (41.945 -87.668)   930.929259
# 557   POINT (40.006 -83.029)   840.512615
# 558   POINT (30.406 -91.186)   725.868192
# 559  POINT (36.107 -115.142)   352.895410
#
# [560 rows x 16 columns]

# %% [markdown]
# ## Write to CSV

# %%
schools.to_csv('../data/cleaned/distances-schools.csv', index=False)
sites.to_csv('../data/cleaned/distances-sites.csv', index=False)
